# %% [markdown]
# # Imports

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import re
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Functions

# %%
def analisar_resultados(df):

    total = len(df)

    df['model_answer'] = df['model_answer'].where(df['model_answer'].isin(['A', 'B', 'C', 'D']), 'invalid')

    acertos = (df['ANSWER'] == df['model_answer']).sum()
    invalidos = (df['model_answer'] == 'invalid').sum()
    erros = total - acertos - invalidos
    erros_com_invalidos = erros + invalidos

    pct_acertos = round((acertos / total) * 100, 2) if total > 0 else 0
    pct_erros = round((erros_com_invalidos / total) * 100, 2) if total > 0 else 0
    pct_invalidos = round((invalidos / total) * 100, 2) if total > 0 else 0

    print("Resumo:")
    print(f"✅ Acertos: {pct_acertos}% (sobre total)")
    print(f"❌ Erros + Inválidos: {pct_erros}% (sobre total)")
    print(f"🚫 Inválidos: {pct_invalidos}% (parte dos erros)")

    return {
        "acertos": acertos,
        "erros": erros,
        "invalidos": invalidos,
        "pct_acertos": pct_acertos,
        "pct_erros": pct_erros,
        "pct_invalidos": pct_invalidos
    }


def extrair_model_answer(texto):
    if not isinstance(texto, str):
        return 'invalid'
    match = re.search(r'[ABCD]', texto)
    return match.group(0) if match else 'invalid'

def analisar_resultados_com_grafico(df, titulo_extra=""):
    total = len(df)

    acertos = (df['ANSWER'] == df['model_answer']).sum()
    invalidos = (df['model_answer'] == 'invalid').sum()
    erros = total - acertos - invalidos

    proporcoes = {
        'Acertos': acertos / total,
        'Erros': erros / total,
        'Inválidos': invalidos / total
    }

    # Impressão dos percentuais
    for k, v in proporcoes.items():
        print(f"{k}: {v:.2%}")

    # Cores: verde (acerto), vermelho (erro), cinza (inválido)
    cores = ['#4CAF50', '#F44336', '#9E9E9E']

    plt.figure(figsize=(6, 6))
    plt.pie(
        proporcoes.values(),
        labels=proporcoes.keys(),
        autopct='%1.1f%%',
        startangle=140,
        colors=cores
    )
    plt.title(f'Distribuição de Respostas {titulo_extra}')
    plt.axis('equal')
    plt.show()

    return proporcoes


def processar_resultados(dir_path, df_answer, results, extrair_model_answer_func, dataset_name, tipo_fine_tune):
    model_names = os.listdir(dir_path)

    for filename in model_names:
        df = pd.read_csv(dir_path + "/" + filename)

        df['output_model'] = df['output_model'].str.upper()

        # Extrai texto depois de qualquer um dos padrões
        df['last_answer'] = df['output_model'].str.extract(
            r'(?:ASSISTANT:|ANSWER:|RESPOSTA:)\s*(.*)', flags=re.IGNORECASE
        ).fillna('invalid')  # ou use seu extrator depois

        df['model_answer'] = df['last_answer'].apply(extrair_model_answer_func)

        df_merged = pd.merge(df, df_answer, on='ID', how='right')

        print(f"\nShape do modelo {filename}: {df_merged.shape}")
        res = analisar_resultados(df_merged)

        results.append({
            'modelos': filename,
            'dataset': dataset_name,
            'tipo': tipo_fine_tune,
            **res
        })



def processar_resultados_english(dir_path, df_answer, results, extrair_model_answer_func, dataset_name, tipo_fine_tune):
    """
    Processa todos os modelos em um diretório e acumula resultados em uma lista externa.

    Parâmetros:
    - dir_path (str): Caminho dos arquivos CSV.
    - df_answer (DataFrame): Respostas corretas com colunas 'ID' e 'ANSWER'.
    - results (list): Lista acumuladora de resultados.
    - dataset (str): Nome do dataset (default: 'pt').
    - tipo (str): Tipo do modelo (default: 'sem_fine_tuning').

    Retorna:
    - None (resultados são adicionados à lista passada)
    """
    model_names = os.listdir(dir_path)

    for filename in model_names:
          
        df = pd.read_csv(dir_path +"/"+ filename )
     
        df['output_model'] = df['output_model'].str.upper()
        df['last_answer'] = df['output_model'].str.split('ANSWER:').str[-1]
        df['model_answer'] = df['last_answer'].apply(extrair_model_answer)

        df_merged = pd.merge(df, df_answer, on='ID', how='right')

        print(f"\nShape do modelo {filename}: {df_merged.shape}")
        res = analisar_resultados(df_merged)

        results.append({
            'modelos': filename,
            'dataset': dataset_name,
            'tipo': tipo_fine_tune,
            **res
        })

# %% [markdown]
# # Data Answers

# %%
df_answer = pd.read_csv('/home/annap/Documents/chatbot_copy/DATASETS/MMLU/0_mmlu_prompt_glosa_pt.csv')
df_answer = df_answer[['ID', 'ANSWER']]
answer_mapping = {0: 'A', 1: 'B', 2: 'C', 3: 'D'}
df_answer['ANSWER'] = df_answer['ANSWER'].map(answer_mapping)
print(df_answer.shape)
df_answer.head()
# Out:
# (15050, 2)
#    ID ANSWER
# 0   0      B
# 1   1      C
# 2   2      D
# 3   3      B
# 4   4      B

# %%
df = pd.read_csv("/home/annap/Documents/chatbot_copy/INFERENCE/DATASETS/UNSLOTH/V1/GLOSA/Qwen2.5-7B-Instruct-bnb-4bit-V1.csv")
df.head()
# Out:
#    ID  \
# 0   0
# 1   1
# 2   2
# 3   3
# 4   4
#
#                                                                                                                                                                                                                                                                                                                                                                                                           prompt  \
# 0                                                                                                Você é um assistente altamente capacitado. Leia a pergunta com atenção e escolha a resposta correta entre as opções (A), (B), (C) ou (D).\n\nPergunta:\nGRAU ENCONTRAR EXTENSÃO CAMPO Q RAIZ QUADRADA 2 RAIZ QUADRADA 3 RAIZ QUADRADA 18 SOBRE Q.\n\nOpções:\n(A) ZERO\n(B) 4\n(C) DOIS.\n(D) SEIS\n\nResposta:
# 1                                                                                                                                 Você é um assistente altamente capacitado. Leia a pergunta com atenção e escolha a resposta correta entre as opções (A), (B), (C) ou (D).\n\nPergunta:\nP 1 2 5 4 2 3 S5 ÍNDICE ENCONTRAR P S5.\n\nOpções:\n(A) OITO\n(B) 2\n(C) VINTE QUATRO.\n(D) CENTO E VINTE\n\nResposta:
# 2                                                          Você é um assistente altamente capacitado. Leia a pergunta com atenção e escolha a resposta correta entre as opções (A), (B), (C) ou (D).\n\nPergunta:\nZERO TODOS ENCONTRAR CAMPO FINITO INDICADO POLINÔMIO COEFICIENTE X 5 MAIS 3 X 3 MAIS X 2 MAIS 2 X Z5.\n\nOpções:\n(A) ZERO\n(B) 1\n(C) ZERO VÍRGULA UM.\n(D) ZERO VÍRGULA QUATRO\n\nResposta:
# 3  Você é um assistente altamente capacitado. Leia a pergunta com atenção e escolha a resposta correta entre as opções (A), (B), (C) ou (D).\n\nPergunta:\nAFIRMAÇÃO 1 GRUPO FATORES GRUPO NÃO-ABELIANO NÃO-ABELIANO. AFIRMAÇÃO 2 K SUBGRUPO NORMAL H H SUBGRUPO NORMAL G K SUBGRUPO NORMAL G.\n\nOpções:\n(A) VERDADE FATO.\n(B) MENTIROSO MENTIROSO\n(C) VERDADEIRO, FALSO.\n(D) FALSO VERDADEIRO\n\nResposta:
# 4                                                    Você é um assistente altamente capacitado. Leia a pergunta com atenção e escolha a resposta correta entre as opções (A), (B), (C) ou (D).\n\nPergunta:\nPRODUTO ENCONTRAR POLINÔMIO ANEL POLINÔMIO F X 4 X MENOS 5 G X 2 X 2 MENOS 4 X MAIS 2 Z8 X.\n\nOpções:\n(A) DOIS X QUADRADO MAIS CINCO\n(B) 6X^2 4X 6 +\n(C) ZERO.\n(D) X DOIS MAIS UM\n\nResposta:
#
#                                                                                                                                                                                                                                                                                                                                                                                                                       output_model
# 0                                                                                                você é um assistente altamente capacitado. leia a pergunta com atenção e escolha a resposta correta entre as opções (a), (b), (c) ou (d).\n\npergunta:\ngrau encontrar extensão campo q raiz quadrada 2 raiz quadrada 3 raiz quadrada 18 sobre q.\n\nopções:\n(a) zero\n(b) 4\n(c) dois.\n(d) seis\n\nresposta: b\nassistant: res
# 1                                                                                                                                 você é um assistente altamente capacitado. leia a pergunta com atenção e escolha a resposta correta entre as opções (a), (b), (c) ou (d).\n\npergunta:\np 1 2 5 4 2 3 s5 índice encontrar p s5.\n\nopções:\n(a) oito\n(b) 2\n(c) vinte quatro.\n(d) cento e vinte\n\nresposta: b\nassistant: res
# 2                                                          você é um assistente altamente capacitado. leia a pergunta com atenção e escolha a resposta correta entre as opções (a), (b), (c) ou (d).\n\npergunta:\nzero todos encontrar campo finito indicado polinômio coeficiente x 5 mais 3 x 3 mais x 2 mais 2 x z5.\n\nopções:\n(a) zero\n(b) 1\n(c) zero vírgula um.\n(d) zero vírgula quatro\n\nresposta: a\nassistant: res
# 3  você é um assistente altamente capacitado. leia a pergunta com atenção e escolha a resposta correta entre as opções (a), (b), (c) ou (d).\n\npergunta:\nafirmação 1 grupo fatores grupo não-abeliano não-abeliano. afirmação 2 k subgrupo normal h h subgrupo normal g k subgrupo normal g.\n\nopções:\n(a) verdade fato.\n(b) mentiroso mentiroso\n(c) verdadeiro, falso.\n(d) falso verdadeiro\n\nresposta: a\nassistant: res
# 4                                                    você é um assistente altamente capacitado. leia a pergunta com atenção e escolha a resposta correta entre as opções (a), (b), (c) ou (d).\n\npergunta:\nproduto encontrar polinômio anel polinômio f x 4 x menos 5 g x 2 x 2 menos 4 x mais 2 z8 x.\n\nopções:\n(a) dois x quadrado mais cinco\n(b) 6x^2 4x 6 +\n(c) zero.\n(d) x dois mais um\n\nresposta: d\nassistant: res

# %%
results = []

# %% [markdown]
# # Portuguese
#
# É o dataset em português, onde foi passado nos modelos do unsloth.

# %%
dir_path_pt = '../UNSLOTH/NO_FINE_TUNE/PT'
dir_path_pt_v1 = '../UNSLOTH/V1/PT_PT'
dir_path_pt_v2 = '../UNSLOTH/V2/PT_PT'


print("Sem Fine Tuning")
processar_resultados(
    dir_path_pt,
    df_answer,
    results,
    extrair_model_answer,
    'pt',
    'sem_fine_tuning'  
)

print("Fine Tuning V1")
processar_resultados(
    dir_path_pt_v1,
    df_answer,
    results,
    extrair_model_answer,
    'pt',
    'v1'  
)

print("Fine Tuning V2")
processar_resultados(
    dir_path_pt_v2,
    df_answer,
    results,
    extrair_model_answer,
    'pt',
    'v2'  
)
# Out:
# Sem Fine Tuning
#
# Shape do modelo gemma-3-12b-it-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 60.93% (sobre total)
# ❌ Erros + Inválidos: 39.07% (sobre total)
# 🚫 Inválidos: 1.86% (parte dos erros)
#
# Shape do modelo zephyr-sft-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 45.09% (sobre total)
# ❌ Erros + Inválidos: 54.91% (sobre total)
# 🚫 Inválidos: 0.07% (parte dos erros)
#
# Shape do modelo Qwen3-14B-unsloth-bnb-4bit-unsloth-largest.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 26.71% (sobre total)
# ❌ Erros + Inválidos: 73.29% (sobre total)
# 🚫 Inválidos: 3.24% (parte dos erros)
#
# Shape do modelo Llama-3.2-3B-Instruct-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 44.19% (sobre total)
# ❌ Erros + Inválidos: 55.81% (sobre total)
# 🚫 Inválidos: 3.23% (parte dos erros)
#
# Shape do modelo Llama-3.1-8B-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 24.81% (sobre total)
# ❌ Erros + Inválidos: 75.19% (sobre total)
# 🚫 Inválidos: 46.64% (parte dos erros)
#
# Shape do modelo Qwen2.5-7B-Instruct-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 56.95% (sobre total)
# ❌ Erros + Inválidos: 43.05% (sobre total)
# 🚫 Inválidos: 3.28% (parte dos erros)
#
# Shape do modelo phi-4-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 0.05% (sobre total)
# ❌ Erros + Inválidos: 99.95% (sobre total)
# 🚫 Inválidos: 99.87% (parte dos erros)
#
# Shape do modelo Qwen2.5-14B-Instruct-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 56.58% (sobre total)
# ❌ Erros + Inválidos: 43.42% (sobre total)
# 🚫 Inválidos: 3.51% (parte dos erros)
#
# Shape do modelo DeepSeek-R1-Distill-Llama-8B.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 37.26% (sobre total)
# ❌ Erros + Inválidos: 62.74% (sobre total)
# 🚫 Inválidos: 3.4% (parte dos erros)
# Fine Tuning V1
#
# Shape do modelo Llama-3.1-8B-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 43.42% (sobre total)
# ❌ Erros + Inválidos: 56.58% (sobre total)
# 🚫 Inválidos: 3.18% (parte dos erros)
#
# Shape do modelo phi-4-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 60.51% (sobre total)
# ❌ Erros + Inválidos: 39.49% (sobre total)
# 🚫 Inválidos: 3.23% (parte dos erros)
#
# Shape do modelo Qwen2.5-7B-Instruct-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 54.59% (sobre total)
# ❌ Erros + Inválidos: 45.41% (sobre total)
# 🚫 Inválidos: 3.06% (parte dos erros)
#
# Shape do modelo zephyr-sft-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 42.12% (sobre total)
# ❌ Erros + Inválidos: 57.88% (sobre total)
# 🚫 Inválidos: 0.34% (parte dos erros)
#
# Shape do modelo gemma-3-12b-it-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 60.93% (sobre total)
# ❌ Erros + Inválidos: 39.07% (sobre total)
# 🚫 Inválidos: 1.86% (parte dos erros)
#
# Shape do modelo Llama-3.2-3B-Instruct-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 41.31% (sobre total)
# ❌ Erros + Inválidos: 58.69% (sobre total)
# 🚫 Inválidos: 3.2% (parte dos erros)
#
# Shape do modelo Qwen2.5-14B-Instruct-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 60.3% (sobre total)
# ❌ Erros + Inválidos: 39.7% (sobre total)
# 🚫 Inválidos: 3.09% (parte dos erros)
# Fine Tuning V2
#
# Shape do modelo Qwen2.5-7B-Instruct-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 41.03% (sobre total)
# ❌ Erros + Inválidos: 58.97% (sobre total)
# 🚫 Inválidos: 16.69% (parte dos erros)
#
# Shape do modelo Llama-3.2-3B-Instruct-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 38.17% (sobre total)
# ❌ Erros + Inválidos: 61.83% (sobre total)
# 🚫 Inválidos: 3.55% (parte dos erros)
#
# Shape do modelo gemma-3-12b-it-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 60.93% (sobre total)
# ❌ Erros + Inválidos: 39.07% (sobre total)
# 🚫 Inválidos: 1.86% (parte dos erros)
#
# Shape do modelo zephyr-sft-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 26.84% (sobre total)
# ❌ Erros + Inválidos: 73.16% (sobre total)
# 🚫 Inválidos: 1.01% (parte dos erros)
#
# Shape do modelo phi-4-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 49.02% (sobre total)
# ❌ Erros + Inválidos: 50.98% (sobre total)
# 🚫 Inválidos: 4.17% (parte dos erros)
#
# Shape do modelo Llama-3.1-8B-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 35.96% (sobre total)
# ❌ Erros + Inválidos: 64.04% (sobre total)
# 🚫 Inválidos: 3.42% (parte dos erros)
#
# Shape do modelo Qwen2.5-14B-Instruct-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 53.73% (sobre total)
# ❌ Erros + Inválidos: 46.27% (sobre total)
# 🚫 Inválidos: 3.44% (parte dos erros)

# %% [markdown]
# # Glosa

# %%
dir_path_gl = '../UNSLOTH/NO_FINE_TUNE/GLOSA'
dir_path_gl_v1 = '../UNSLOTH/V1/GLOSA'
dir_path_gl_v2 = '../UNSLOTH/V2/GLOSA'

print("Sem Fine Tuning")
processar_resultados(
    dir_path_gl,
    df_answer,
    results,
    extrair_model_answer,
    'glosa',
    'sem_fine_tuning'  
)

print("Fine Tuning V1")
processar_resultados(
    dir_path_gl_v1,
    df_answer,
    results,
    extrair_model_answer,
    'glosa',
    'v1'  
)

print("Fine Tuning V2")
processar_resultados(
    dir_path_gl_v2,
    df_answer,
    results,
    extrair_model_answer,
    'glosa',
    'v2'  
)
# Out:
# Sem Fine Tuning
#
# Shape do modelo gemma-3-12b-it-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 45.29% (sobre total)
# ❌ Erros + Inválidos: 54.71% (sobre total)
# 🚫 Inválidos: 0.47% (parte dos erros)
#
# Shape do modelo zephyr-sft-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 33.82% (sobre total)
# ❌ Erros + Inválidos: 66.18% (sobre total)
# 🚫 Inválidos: 0.01% (parte dos erros)
#
# Shape do modelo Qwen3-14B-unsloth-bnb-4bit-unsloth-largest.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 24.24% (sobre total)
# ❌ Erros + Inválidos: 75.76% (sobre total)
# 🚫 Inválidos: 0.9% (parte dos erros)
#
# Shape do modelo Llama-3.2-3B-Instruct-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 33.77% (sobre total)
# ❌ Erros + Inválidos: 66.23% (sobre total)
# 🚫 Inválidos: 0.88% (parte dos erros)
#
# Shape do modelo Llama-3.1-8B-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 14.58% (sobre total)
# ❌ Erros + Inválidos: 85.42% (sobre total)
# 🚫 Inválidos: 53.84% (parte dos erros)
#
# Shape do modelo Qwen2.5-7B-Instruct-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 40.74% (sobre total)
# ❌ Erros + Inválidos: 59.26% (sobre total)
# 🚫 Inválidos: 0.91% (parte dos erros)
#
# Shape do modelo Qwen2.5-32B-Instruct-bnb-4bit-unsloth-largest.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 32.19% (sobre total)
# ❌ Erros + Inválidos: 67.81% (sobre total)
# 🚫 Inválidos: 0.86% (parte dos erros)
#
# Shape do modelo phi-4-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 0.01% (sobre total)
# ❌ Erros + Inválidos: 99.99% (sobre total)
# 🚫 Inválidos: 99.99% (parte dos erros)
#
# Shape do modelo Qwen2.5-14B-Instruct-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 39.89% (sobre total)
# ❌ Erros + Inválidos: 60.11% (sobre total)
# 🚫 Inválidos: 0.86% (parte dos erros)
#
# Shape do modelo DeepSeek-R1-Distill-Llama-8B.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 28.45% (sobre total)
# ❌ Erros + Inválidos: 71.55% (sobre total)
# 🚫 Inválidos: 0.97% (parte dos erros)
# Fine Tuning V1
#
# Shape do modelo Llama-3.1-8B-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 35.89% (sobre total)
# ❌ Erros + Inválidos: 64.11% (sobre total)
# 🚫 Inválidos: 0.92% (parte dos erros)
#
# Shape do modelo phi-4-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 47.97% (sobre total)
# ❌ Erros + Inválidos: 52.03% (sobre total)
# 🚫 Inválidos: 0.84% (parte dos erros)
#
# Shape do modelo Qwen2.5-7B-Instruct-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 45.3% (sobre total)
# ❌ Erros + Inválidos: 54.7% (sobre total)
# 🚫 Inválidos: 0.83% (parte dos erros)
#
# Shape do modelo zephyr-sft-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 35.11% (sobre total)
# ❌ Erros + Inválidos: 64.89% (sobre total)
# 🚫 Inválidos: 0.06% (parte dos erros)
#
# Shape do modelo gemma-3-12b-it-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 45.29% (sobre total)
# ❌ Erros + Inválidos: 54.71% (sobre total)
# 🚫 Inválidos: 0.47% (parte dos erros)
#
# Shape do modelo Llama-3.2-3B-Instruct-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 34.21% (sobre total)
# ❌ Erros + Inválidos: 65.79% (sobre total)
# 🚫 Inválidos: 0.83% (parte dos erros)
#
# Shape do modelo Qwen2.5-14B-Instruct-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 50.09% (sobre total)
# ❌ Erros + Inválidos: 49.91% (sobre total)
# 🚫 Inválidos: 0.82% (parte dos erros)
# Fine Tuning V2
#
# Shape do modelo Qwen2.5-7B-Instruct-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 33.81% (sobre total)
# ❌ Erros + Inválidos: 66.19% (sobre total)
# 🚫 Inválidos: 17.67% (parte dos erros)
#
# Shape do modelo Llama-3.2-3B-Instruct-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 33.28% (sobre total)
# ❌ Erros + Inválidos: 66.72% (sobre total)
# 🚫 Inválidos: 1.1% (parte dos erros)
#
# Shape do modelo gemma-3-12b-it-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 45.29% (sobre total)
# ❌ Erros + Inválidos: 54.71% (sobre total)
# 🚫 Inválidos: 0.47% (parte dos erros)
#
# Shape do modelo zephyr-sft-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 26.84% (sobre total)
# ❌ Erros + Inválidos: 73.16% (sobre total)
# 🚫 Inválidos: 0.71% (parte dos erros)
#
# Shape do modelo phi-4-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 40.98% (sobre total)
# ❌ Erros + Inválidos: 59.02% (sobre total)
# 🚫 Inválidos: 2.29% (parte dos erros)
#
# Shape do modelo Llama-3.1-8B-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 32.32% (sobre total)
# ❌ Erros + Inválidos: 67.68% (sobre total)
# 🚫 Inválidos: 1.14% (parte dos erros)
#
# Shape do modelo Qwen2.5-14B-Instruct-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 43.82% (sobre total)
# ❌ Erros + Inválidos: 56.18% (sobre total)
# 🚫 Inválidos: 1.2% (parte dos erros)

# %% [markdown]
# # English
#
# Esse tem que fazer para o v1 e o V2 tbm

# %%
dir_path_eng = '../UNSLOTH/NO_FINE_TUNE/ENG'
dir_path_eng_v1 = '../UNSLOTH/V1/ENG'
dir_path_eng_v2 = '../UNSLOTH/V2/ENG'


print("Sem Fine Tuning")
processar_resultados(
    dir_path_eng,
    df_answer,
    results,
    extrair_model_answer,
    'english',
    'sem_fine_tuning'  
)

print("Fine Tuning V1")
processar_resultados(
    dir_path_eng_v1,
    df_answer,
    results,
    extrair_model_answer,
    'english',
    'v1'  
)

print("Fine Tuning V2")
processar_resultados(
    dir_path_eng_v2,
    df_answer,
    results,
    extrair_model_answer,
    'english',
    'v2'  
)
# Out:
# Sem Fine Tuning
#
# Shape do modelo gemma-3-12b-it-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 71.34% (sobre total)
# ❌ Erros + Inválidos: 28.66% (sobre total)
# 🚫 Inválidos: 0.06% (parte dos erros)
#
# Shape do modelo zephyr-sft-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 56.91% (sobre total)
# ❌ Erros + Inválidos: 43.09% (sobre total)
# 🚫 Inválidos: 0.16% (parte dos erros)
#
# Shape do modelo Qwen3-14B-unsloth-bnb-4bit-unsloth-largest.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 28.91% (sobre total)
# ❌ Erros + Inválidos: 71.09% (sobre total)
# 🚫 Inválidos: 4.91% (parte dos erros)
#
# Shape do modelo Llama-3.2-3B-Instruct-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 59.34% (sobre total)
# ❌ Erros + Inválidos: 40.66% (sobre total)
# 🚫 Inválidos: 0.07% (parte dos erros)
#
# Shape do modelo Llama-3.1-8B-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 54.76% (sobre total)
# ❌ Erros + Inválidos: 45.24% (sobre total)
# 🚫 Inválidos: 0.5% (parte dos erros)
#
# Shape do modelo Qwen2.5-7B-Instruct-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 68.45% (sobre total)
# ❌ Erros + Inválidos: 31.55% (sobre total)
# 🚫 Inválidos: 0.1% (parte dos erros)
#
# Shape do modelo phi-4-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 47.39% (sobre total)
# ❌ Erros + Inválidos: 52.61% (sobre total)
# 🚫 Inválidos: 39.4% (parte dos erros)
#
# Shape do modelo Qwen2.5-14B-Instruct-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 53.08% (sobre total)
# ❌ Erros + Inválidos: 46.92% (sobre total)
# 🚫 Inválidos: 0.27% (parte dos erros)
#
# Shape do modelo DeepSeek-R1-Distill-Llama-8B.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 53.25% (sobre total)
# ❌ Erros + Inválidos: 46.75% (sobre total)
# 🚫 Inválidos: 0.06% (parte dos erros)
# Fine Tuning V1
#
# Shape do modelo Llama-3.1-8B-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 56.52% (sobre total)
# ❌ Erros + Inválidos: 43.48% (sobre total)
# 🚫 Inválidos: 0.96% (parte dos erros)
#
# Shape do modelo phi-4-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 74.98% (sobre total)
# ❌ Erros + Inválidos: 25.02% (sobre total)
# 🚫 Inválidos: 0.8% (parte dos erros)
#
# Shape do modelo Qwen2.5-7B-Instruct-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 67.61% (sobre total)
# ❌ Erros + Inválidos: 32.39% (sobre total)
# 🚫 Inválidos: 0.88% (parte dos erros)
#
# Shape do modelo zephyr-sft-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 52.06% (sobre total)
# ❌ Erros + Inválidos: 47.94% (sobre total)
# 🚫 Inválidos: 3.24% (parte dos erros)
#
# Shape do modelo gemma-3-12b-it-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 70.66% (sobre total)
# ❌ Erros + Inválidos: 29.34% (sobre total)
# 🚫 Inválidos: 1.02% (parte dos erros)
#
# Shape do modelo Llama-3.2-3B-Instruct-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 54.31% (sobre total)
# ❌ Erros + Inválidos: 45.69% (sobre total)
# 🚫 Inválidos: 0.82% (parte dos erros)
#
# Shape do modelo Qwen2.5-14B-Instruct-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 73.21% (sobre total)
# ❌ Erros + Inválidos: 26.79% (sobre total)
# 🚫 Inválidos: 0.86% (parte dos erros)
# Fine Tuning V2
#
# Shape do modelo Qwen2.5-7B-Instruct-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 60.92% (sobre total)
# ❌ Erros + Inválidos: 39.08% (sobre total)
# 🚫 Inválidos: 1.87% (parte dos erros)
#
# Shape do modelo Llama-3.2-3B-Instruct-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 47.73% (sobre total)
# ❌ Erros + Inválidos: 52.27% (sobre total)
# 🚫 Inválidos: 0.96% (parte dos erros)
#
# Shape do modelo zephyr-sft-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 28.75% (sobre total)
# ❌ Erros + Inválidos: 71.25% (sobre total)
# 🚫 Inválidos: 5.79% (parte dos erros)
#
# Shape do modelo phi-4-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 71.15% (sobre total)
# ❌ Erros + Inválidos: 28.85% (sobre total)
# 🚫 Inválidos: 1.14% (parte dos erros)
#
# Shape do modelo Llama-3.1-8B-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 45.19% (sobre total)
# ❌ Erros + Inválidos: 54.81% (sobre total)
# 🚫 Inválidos: 1.75% (parte dos erros)
#
# Shape do modelo Qwen2.5-14B-Instruct-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 56.52% (sobre total)
# ❌ Erros + Inválidos: 43.48% (sobre total)
# 🚫 Inválidos: 1.02% (parte dos erros)

# %% [markdown]
# # GLOSA PT

# %%
dir_path_gl_pt = '../UNSLOTH/NO_FINE_TUNE/GLOSA_PT'
dir_path_gl_pt_v1 = '../UNSLOTH/V1/GLOSA_PT'
dir_path_gl_pt_v2 = '../UNSLOTH/V2/GLOSA_PT'

print("Sem Fine Tuning")
processar_resultados(
    dir_path_gl_pt,
    df_answer,
    results,
    extrair_model_answer,
    'glosa_pt',
    'sem_fine_tuning'  
)

print("Fine Tuning V1")
processar_resultados(
    dir_path_gl_pt_v1,
    df_answer,
    results,
    extrair_model_answer,
    'glosa_pt',
    'v1'  
)

print("Fine Tuning V2")
processar_resultados(
    dir_path_gl_pt_v2,
    df_answer,
    results,
    extrair_model_answer,
    'glosa_pt',
    'v2'  
)
# Out:
# Sem Fine Tuning
#
# Shape do modelo gemma-3-12b-it-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 52.72% (sobre total)
# ❌ Erros + Inválidos: 47.28% (sobre total)
# 🚫 Inválidos: 0.46% (parte dos erros)
#
# Shape do modelo zephyr-sft-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 38.4% (sobre total)
# ❌ Erros + Inválidos: 61.6% (sobre total)
# 🚫 Inválidos: 0.02% (parte dos erros)
#
# Shape do modelo Qwen3-14B-unsloth-bnb-4bit-unsloth-largest.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 24.65% (sobre total)
# ❌ Erros + Inválidos: 75.35% (sobre total)
# 🚫 Inválidos: 0.86% (parte dos erros)
#
# Shape do modelo Llama-3.2-3B-Instruct-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 38.8% (sobre total)
# ❌ Erros + Inválidos: 61.2% (sobre total)
# 🚫 Inválidos: 0.84% (parte dos erros)
#
# Shape do modelo Llama-3.1-8B-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 15.76% (sobre total)
# ❌ Erros + Inválidos: 84.24% (sobre total)
# 🚫 Inválidos: 57.76% (parte dos erros)
#
# Shape do modelo Qwen2.5-7B-Instruct-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 48.52% (sobre total)
# ❌ Erros + Inválidos: 51.48% (sobre total)
# 🚫 Inválidos: 0.86% (parte dos erros)
#
# Shape do modelo phi-4-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 0.01% (sobre total)
# ❌ Erros + Inválidos: 99.99% (sobre total)
# 🚫 Inválidos: 99.98% (parte dos erros)
#
# Shape do modelo Qwen2.5-14B-Instruct-unsloth-bnb-4bit.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 48.14% (sobre total)
# ❌ Erros + Inválidos: 51.86% (sobre total)
# 🚫 Inválidos: 0.84% (parte dos erros)
#
# Shape do modelo DeepSeek-R1-Distill-Llama-8B.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 31.65% (sobre total)
# ❌ Erros + Inválidos: 68.35% (sobre total)
# 🚫 Inválidos: 1.0% (parte dos erros)
# Fine Tuning V1
#
# Shape do modelo Llama-3.1-8B-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 39.63% (sobre total)
# ❌ Erros + Inválidos: 60.37% (sobre total)
# 🚫 Inválidos: 0.81% (parte dos erros)
#
# Shape do modelo phi-4-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 53.54% (sobre total)
# ❌ Erros + Inválidos: 46.46% (sobre total)
# 🚫 Inválidos: 0.83% (parte dos erros)
#
# Shape do modelo Qwen2.5-7B-Instruct-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 49.54% (sobre total)
# ❌ Erros + Inválidos: 50.46% (sobre total)
# 🚫 Inválidos: 0.82% (parte dos erros)
#
# Shape do modelo zephyr-sft-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 38.07% (sobre total)
# ❌ Erros + Inválidos: 61.93% (sobre total)
# 🚫 Inválidos: 0.23% (parte dos erros)
#
# Shape do modelo gemma-3-12b-it-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 52.72% (sobre total)
# ❌ Erros + Inválidos: 47.28% (sobre total)
# 🚫 Inválidos: 0.46% (parte dos erros)
#
# Shape do modelo Llama-3.2-3B-Instruct-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 38.31% (sobre total)
# ❌ Erros + Inválidos: 61.69% (sobre total)
# 🚫 Inválidos: 0.82% (parte dos erros)
#
# Shape do modelo Qwen2.5-14B-Instruct-unsloth-bnb-4bit-V1.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 54.58% (sobre total)
# ❌ Erros + Inválidos: 45.42% (sobre total)
# 🚫 Inválidos: 0.81% (parte dos erros)
# Fine Tuning V2
#
# Shape do modelo Qwen2.5-7B-Instruct-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 37.3% (sobre total)
# ❌ Erros + Inválidos: 62.7% (sobre total)
# 🚫 Inválidos: 15.57% (parte dos erros)
#
# Shape do modelo Llama-3.2-3B-Instruct-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 36.19% (sobre total)
# ❌ Erros + Inválidos: 63.81% (sobre total)
# 🚫 Inválidos: 1.12% (parte dos erros)
#
# Shape do modelo gemma-3-12b-it-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 52.72% (sobre total)
# ❌ Erros + Inválidos: 47.28% (sobre total)
# 🚫 Inválidos: 0.46% (parte dos erros)
#
# Shape do modelo zephyr-sft-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 27.07% (sobre total)
# ❌ Erros + Inválidos: 72.93% (sobre total)
# 🚫 Inválidos: 0.9% (parte dos erros)
#
# Shape do modelo phi-4-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 43.46% (sobre total)
# ❌ Erros + Inválidos: 56.54% (sobre total)
# 🚫 Inválidos: 2.15% (parte dos erros)
#
# Shape do modelo Llama-3.1-8B-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 34.59% (sobre total)
# ❌ Erros + Inválidos: 65.41% (sobre total)
# 🚫 Inválidos: 0.99% (parte dos erros)
#
# Shape do modelo Qwen2.5-14B-Instruct-unsloth-bnb-4bit-V2.csv: (15050, 6)
# Resumo:
# ✅ Acertos: 48.39% (sobre total)
# ❌ Erros + Inválidos: 51.61% (sobre total)
# 🚫 Inválidos: 1.16% (parte dos erros)

# %% [markdown]
# # Results

# %%
df_results = pd.DataFrame(results)
df_results.tail(10)
# Out:
#                                           modelos   dataset tipo  acertos  \
# 82                 gemma-3-12b-it-bnb-4bit-V1.csv  glosa_pt   v1     7934
# 83  Llama-3.2-3B-Instruct-unsloth-bnb-4bit-V1.csv  glosa_pt   v1     5765
# 84   Qwen2.5-14B-Instruct-unsloth-bnb-4bit-V1.csv  glosa_pt   v1     8215
# 85            Qwen2.5-7B-Instruct-bnb-4bit-V2.csv  glosa_pt   v2     5613
# 86  Llama-3.2-3B-Instruct-unsloth-bnb-4bit-V2.csv  glosa_pt   v2     5446
# 87                 gemma-3-12b-it-bnb-4bit-V2.csv  glosa_pt   v2     7934
# 88                     zephyr-sft-bnb-4bit-V2.csv  glosa_pt   v2     4074
# 89                  phi-4-unsloth-bnb-4bit-V2.csv  glosa_pt   v2     6541
# 90           Llama-3.1-8B-unsloth-bnb-4bit-V2.csv  glosa_pt   v2     5206
# 91   Qwen2.5-14B-Instruct-unsloth-bnb-4bit-V2.csv  glosa_pt   v2     7283
#
#     erros  invalidos  pct_acertos  pct_erros  pct_invalidos
# 82   7047         69        52.72      47.28           0.46
# 83   9162        123        38.31      61.69           0.82
# 84   6713        122        54.58      45.42           0.81
# 85   7094       2343        37.30      62.70          15.57
# 86   9435        169        36.19      63.81           1.12
# 87   7047         69        52.72      47.28           0.46
# 88  10840        136        27.07      72.93           0.90
# 89   8186        323        43.46      56.54           2.15
# 90   9695        149        34.59      65.41           0.99
# 91   7593        174        48.39      51.61           1.16

# %%
df_results.to_csv("results_all_models.csv", index=False)
